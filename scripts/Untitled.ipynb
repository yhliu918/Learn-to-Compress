# %%
from pyecharts.charts import Bar
from pyecharts.faker import Faker
from pyecharts import options as opts

import random

# %%
x_vals = ['linear','normal','lognormal','books','gap','fb','wiki','newman']
bar = (
    Bar()
    .add_xaxis(x_vals)
    .add_yaxis("Our", [6.7, 6.99, 6.828,27.72,16.16, 43.54,4.328, 8.869])
    .add_yaxis("FOR", [47.2,42.53,27.26,39.46,34.7,56.75,1.787,11.68])
    .add_yaxis("Delta", [15.9,11.45,4.191,19.5,9.638,35.36,0.8583,4.656])
    .add_yaxis("RLE", [100,100,68.78,100,100,100,2.149,16.05])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_size=14))
    .set_global_opts(title_opts=opts.TitleOpts(title='R', subtitle="QDM"),
                     xaxis_opts=opts.AxisOpts(name='Dataset'),
                     yaxis_opts=opts.AxisOpts(name='%'))
)
# bar.render('柱状图.html')
# 或者
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f81184f8d76246ca9b46fffb9b7aa34b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f81184f8d76246ca9b46fffb9b7aa34b = echarts.init(
#                     document.getElementById('f81184f8d76246ca9b46fffb9b7aa34b'), 'white', {renderer: 'canvas'});
#                 var option_f81184f8d76246ca9b46fffb9b7aa34b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_vals = ['Linear','Normal','Books','Fb','Wiki']
bar = (
    Bar()
    .add_xaxis(x_vals)
    .add_yaxis("Our", [6.70, 6.99, 27.72, 43.54,4.33])
    .add_yaxis("FOR", [47.20,42.53,39.46,56.75,1.79])
    .add_yaxis("Delta", [15.90,11.45,19.50,35.36,0.86])
    .add_yaxis("RLE", [100.0,100.0,100.0,100.0,2.15])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_size=14))
    .set_global_opts(title_opts=opts.TitleOpts(title='Compression rate'),
                     xaxis_opts=opts.AxisOpts(name='Dataset'),
                     yaxis_opts=opts.AxisOpts(name='%'))
)
# bar.render('柱状图.html')
# 或者
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="20c19eb14e014b3e9e0d7d7bbdc432e8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_20c19eb14e014b3e9e0d7d7bbdc432e8 = echarts.init(
#                     document.getElementById('20c19eb14e014b3e9e0d7d7bbdc432e8'), 'white', {renderer: 'canvas'});
#                 var option_20c19eb14e014b3e9e0d7d7bbdc432e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_vals = ['Linear','Normal','Books','Fb','Wiki']
bar = (
    Bar()
    .add_xaxis(x_vals)
    .add_yaxis("Our", [1.64, 1.65, 1.46, 1.33, 1.67])
    .add_yaxis("FOR", [1579391800,1653572800,1690149300,1733505700,3394688100])
    .add_yaxis("Delta", [1379025400,1461694800,1324575800,1256443500,3474611000])
    .add_yaxis("RLE", [839457020,836283790,821566010,921790000,921790000])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_size=12))
    .set_global_opts(title_opts=opts.TitleOpts(title='Compression Throughput'),
                     xaxis_opts=opts.AxisOpts(name='Dataset'),
                     yaxis_opts=opts.AxisOpts(name='records / s'))
)
# bar.render('柱状图.html')
# 或者
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="59ff26037f664460975b1e4970da6585" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_59ff26037f664460975b1e4970da6585 = echarts.init(
#                     document.getElementById('59ff26037f664460975b1e4970da6585'), 'white', {renderer: 'canvas'});
#                 var option_59ff26037f664460975b1e4970da6585 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_vals = ['Linear','Normal','Books','Fb','Wiki']
bar = (
    Bar()
    .add_xaxis(x_vals)
    .add_yaxis("Our", [2.30, 2.30, 2.97, 3.55, 2.23])
    .add_yaxis("FOR", [0.87,0.86,0.74,0.70,0.37])
    .add_yaxis("Delta", [1.77,1.75,1.80,1.89,0.78])
    .add_yaxis("RLE", [1.47,1.50,1.46,1.32,0.36])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_size=14))
    .set_global_opts(title_opts=opts.TitleOpts(title='Decode all Latency'),
                     xaxis_opts=opts.AxisOpts(name='Dataset'),
                     yaxis_opts=opts.AxisOpts(name='ns / record'))
)
# bar.render('柱状图.html')
# 或者
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f7d0727b21824b17aed89f57775b0483" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f7d0727b21824b17aed89f57775b0483 = echarts.init(
#                     document.getElementById('f7d0727b21824b17aed89f57775b0483'), 'white', {renderer: 'canvas'});
#                 var option_f7d0727b21824b17aed89f57775b0483 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_vals = ['Linear','Normal','Books','Fb','Wiki']
bar = (
    Bar()
    .add_xaxis(x_vals)
    .add_yaxis("Our", [10.23,10.24,11.44,11.95,10.04])
    .add_yaxis("FOR", [8.94,8.94,8.97,9.89,5.33])
    .add_yaxis("Delta", [939.40,960.02,945.52,1087.79,138.40])
    .add_yaxis("RLE", [296.23,296.22,296.31,296.63,5.66])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, font_size=12))
    .set_global_opts(title_opts=opts.TitleOpts(title='Random access Latency'),
                     xaxis_opts=opts.AxisOpts(name='Dataset'),
                     yaxis_opts=opts.AxisOpts(name='ns / record'))
)
# bar.render('柱状图.html')
# 或者
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="587b641ac8b545d5820eb8ba1272c206" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_587b641ac8b545d5820eb8ba1272c206 = echarts.init(
#                     document.getElementById('587b641ac8b545d5820eb8ba1272c206'), 'white', {renderer: 'canvas'});
#                 var option_587b641ac8b545d5820eb8ba1272c206 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import random
from pyecharts import options as  opts
from pyecharts.charts import Scatter3D
from pyecharts.faker import Faker

Scatter_data = [(0.95,14.84,47.2),(1.23, 1000,200),(1.77,1000,15.9),(1.20, 1000,100),(2.42, 1000,123.4),(2.74,17.28,6.48)]
c = (
    Scatter3D(init_opts = opts.InitOpts(width='600px',height='600px'))  #初始化
    .add("FOR",[(0.95,14.84,47.2)])
    .add("RLE",[(1.23, 1000,200)])
    .add("Delta",[(1.77,1000,15.9)])
    #设置全局配置项
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Codec"),  #添加标题
        visualmap_opts=opts.VisualMapOpts(
            max_=200, #最大值
            pos_top=50, # visualMap 组件离容器上侧的距离
            range_color=Faker.visual_color  #颜色映射                                         
        )
    )
#     .render("3D散点图.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="88b4ce84db8340a38ba31e8d07df7f70" style="width:600px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_88b4ce84db8340a38ba31e8d07df7f70 = echarts.init(
#                     document.getElementById('88b4ce84db8340a38ba31e8d07df7f70'), 'white', {renderer: 'canvas'});
#                 var option_88b4ce84db8340a38ba31e8d07df7f70 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
import math

from pyecharts.charts import Surface3D


def create_surface3d_data():
    for t0 in range(-60, 60, 1):
        y = t0 / 60
        for t1 in range(-60, 60, 1):
            x = t1 / 60
            if math.fabs(x) < 0.1 and math.fabs(y) < 0.1:
                z = '-'
            else:
                z = math.sin(x * math.pi) * math.sin(y * math.pi)
            yield [x, y, z]

range_color = [
    "#313695",
    "#4575b4",
    "#74add1",
    "#abd9e9",
    "#e0f3f8",
    "#ffffbf",
    "#fee090",
    "#fdae61",
    "#f46d43",
    "#d73027",
    "#a50026",
]

_data = list(create_surface3d_data())
surface3d = Surface3D(init_opts = opts.InitOpts(width='900px',height='600px'))
surface3d.add(
    "",
    _data,
)
surface3d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="9d4ec893026b4c0c98d25ca5771f7567" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_9d4ec893026b4c0c98d25ca5771f7567 = echarts.init(
#                     document.getElementById('9d4ec893026b4c0c98d25ca5771f7567'), 'white', {renderer: 'canvas'});
#                 var option_9d4ec893026b4c0c98d25ca5771f7567 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
import matplotlib as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import math
plt.rcParams['legend.fontsize'] = 10


data = np.array([[0.95,14.84,47.2],[1.20, 1000,100],[1.23, 1000,200],[1.77,1000,15.9],[2.42, 1000,123.4],[2.74,17.28,6.48]])


fig = plt.figure(figsize=(6, 6.5))
ax = fig.gca(projection='3d')

null = [0]*len(data)
xs = data[:,0]
ys = data[:,1]
zs = data[:,2]
names = ['FOR','Snappy','RLE','Delta','MaskVB','ours']
for  x, y, z,name in zip( xs, ys, zs, names):
    label = str(name)
    ax.text(x-0.13, y-10, z+15, label)

ax.scatter(xs,ys,zs,s=70)
plt.plot(xs,ys,null)
ax.set_xlim(0, 4)
ax.set_ylim(1000, 0)


ax.set_zlabel('R', fontdict={'size': 10, 'color': 'blue'})
ax.set_ylabel('T_ra', fontdict={'size': 10, 'color': 'blue'})
ax.set_xlabel('T_da', fontdict={'size': 10, 'color': 'blue'})
# Out:
# <ipython-input-83-0aadf341d381>:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# Text(0.5, 0, 'T_da')

# %%
# -*- coding: utf-8 -*-
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
 
fig = plt.figure()
ax = Axes3D(fig)
data = np.array([[0.95,14.84,47.2],[1.23, 1000,200],[1.77,1000,15.9],[1.20, 1000,100],[2.42, 1000,123.4],[2.74,17.28,6.48]])

X = data[:,0]
Y = data[:,1]
Z = data[:,2].reshape([1,-1])
X, Y = np.meshgrid(X, Y)

 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='rainbow')
 
plt.draw()
# Out:
# <ipython-input-70-c4df72bede63>:7: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
